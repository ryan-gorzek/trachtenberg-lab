# %%
import scanpy as sc
import numpy as np
import random
sc.settings.verbosity = 3
sc.set_figure_params(dpi=100)

adata = sc.read_h5ad("E:/Mouse_V1/P38NR/P38_gaba.h5ad")
# adata = sc.read_h5ad("E:/Projection-seq/Projection_Seq_GABA.h5ad")
adata.X = adata.raw.X

# %%
sc.pl.umap(adata, color = ["Chrm1", "Chrm2", "Chrm3", "Chrm4", "Chrm5", "Chrna1", "Chrna2", "Chrna3", "Chrna4", "Chrna5", "Chrna6", "Chrna7"])

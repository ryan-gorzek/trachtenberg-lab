# %% [markdown]
# UPB1

# %%
sequence = "..."
upper = [base.upper() for base in sequence]
"".join(upper)
# Out:
# '...'

# %% [markdown]
# UPB2

# %%
sequence = "..."
upper = [base.upper() for base in sequence]
"".join(upper)
# Out:
# '...'

# %% [markdown]
# UPB4

# %%
sequence = "..."
upper = [base.upper() for base in sequence]
"".join(upper)
# Out:
# '...'

# %% [markdown]
# UPB5

# %%
sequence = "..."
upper = [base.upper() for base in sequence]
"".join(upper)
# Out:
# '...'

# %% [markdown]
# UPB6

# %%
sequence = "..."
upper = [base.upper() for base in sequence]
"".join(upper)
# Out:
# '...'

# %% [markdown]
# UPB7

# %%
sequence = "..."
upper = [base.upper() for base in sequence]
"".join(upper)
# Out:
# '...'

# %% [markdown]
# tdTomato

# %%
sequence = "..."
upper = [base.upper() for base in sequence]
"".join(upper)
# Out:
# '...'

# %% [markdown]
# WPRE

# %%
sequence = "..."
upper = [base.upper() for base in sequence]
"".join(upper)
# Out:
# '...'

# %%
import scanpy as sc
import numpy as np

adata_raw = sc.read_10x_h5("E:/raw_feature_bc_matrix.h5")
adata_filt = sc.read_10x_h5("E:/filtered_feature_bc_matrix.h5")
# Out:
# c:\Users\TLab\anaconda3\envs\scanpy\lib\site-packages\anndata\_core\anndata.py:1832: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# c:\Users\TLab\anaconda3\envs\scanpy\lib\site-packages\anndata\_core\anndata.py:1832: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
np.sum(adata_raw[:, "UPB1"].X)
# Out:
# 3768

# %%
adata_raw[:, "UPB1"].X
# Out:
# <1922602x1 sparse matrix of type '<class 'numpy.float32'>'
# 	with 3768 stored elements in Compressed Sparse Row format>

# %%
np.sum(adata_filt[:, "UPB1"].X > 0)
# Out:
# 517
